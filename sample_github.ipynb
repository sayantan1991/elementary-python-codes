# %% [markdown]
# <a href="https://colab.research.google.com/github/sayantan1991/elementary-python-codes/blob/main/sample_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Create a directory named 'my_folder'
os.makedirs("my_folder", exist_ok=True)

# You can also create nested directories
os.makedirs("data/train/images", exist_ok=True)
